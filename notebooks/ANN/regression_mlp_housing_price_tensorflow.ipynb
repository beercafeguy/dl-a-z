# %% [markdown]
# # Import Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


import tensorflow as tf
import tensorflow.keras as keras

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
housing_data = fetch_california_housing()
X = housing_data.data
y = housing_data.target

# %%
print(X[1:3])
print(y[1:3])
# Out:
# [[ 8.30140000e+00  2.10000000e+01  6.23813708e+00  9.71880492e-01
#    2.40100000e+03  2.10984183e+00  3.78600000e+01 -1.22220000e+02]
#  [ 7.25740000e+00  5.20000000e+01  8.28813559e+00  1.07344633e+00
#    4.96000000e+02  2.80225989e+00  3.78500000e+01 -1.22240000e+02]]
# [3.585 3.521]

# %%
housing_data.feature_names
# Out:
# ['MedInc',
#  'HouseAge',
#  'AveRooms',
#  'AveBedrms',
#  'Population',
#  'AveOccup',
#  'Latitude',
#  'Longitude']

# %% [markdown]
# # Split train test

# %%
X_temp, X_test,y_temp,y_test = train_test_split(
    X,
    y,
    random_state=2024,
    test_size=0.2
)

X_train, X_valid,y_train, y_valid = train_test_split(
    X_temp,
    y_temp,
    random_state=2024,
    test_size=0.2
)

# %% [markdown]
# # Train model

# %%
tf.random.set_seed(42)
norm_layer = tf.keras.layers.Normalization(input_shape=X_train.shape[1:])
model = tf.keras.Sequential([
    norm_layer,
    tf.keras.layers.Dense(50, activation="relu"),
    tf.keras.layers.Dense(50, activation="relu"),
    tf.keras.layers.Dense(50, activation="relu"),
    tf.keras.layers.Dense(1)
])
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
model.compile(loss="mse", optimizer=optimizer, metrics=["RootMeanSquaredError"])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization (Normalizati  (None, 8)                 17
#  on)
#
#  dense (Dense)               (None, 50)                450
#
#  dense_1 (Dense)             (None, 50)                2550
#
#  dense_2 (Dense)             (None, 50)                2550
#
#  dense_3 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 5618 (21.95 KB)
# Trainable params: 5601 (21.88 KB)
# Non-trainable params: 17 (72.00 Byte)
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model, "housing_price_model.png", show_shapes=True)

# %%
# calculate mean and std

norm_layer.adapt(X_train)

# %%
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 413/413 [==============================] - 1s 2ms/step - loss: 0.7330 - root_mean_squared_error: 0.8562 - val_loss: 0.4448 - val_root_mean_squared_error: 0.6669
# Epoch 2/20
# 413/413 [==============================] - 1s 2ms/step - loss: 0.4008 - root_mean_squared_error: 0.6331 - val_loss: 0.4062 - val_root_mean_squared_error: 0.6373
# Epoch 3/20
# 413/413 [==============================] - 1s 2ms/step - loss: 0.3758 - root_mean_squared_error: 0.6131 - val_loss: 0.3760 - val_root_mean_squared_error: 0.6132
# Epoch 4/20
# 413/413 [==============================] - 1s 2ms/step - loss: 0.3528 - root_mean_squared_error: 0.5940 - val_loss: 0.3701 - val_root_mean_squared_error: 0.6084
# Epoch 5/20
# 413/413 [==============================] - 1s 2ms/step - loss: 0.3309 - root_mean_squared_error: 0.5753 - val_loss: 0.3838 - val_root_mean_squared_error: 0.6195
# Epoch 6/20
# 413/413 [==============================] - 1s 2ms/step - loss: 0.3236 - root_mean_squared_error: 0.5689 - val_loss: 0.3567 - val_root_mean_squared_error: 0.5973
# Epoch 7/20
# 413/413 [==============================] - 1s 2ms/step - loss: 0.3154 - root_mean_squared_error: 0.5616 - val_loss: 0.3305 - val_root_mean_squared_error: 0.5749
# Epoch 8/20
# 413/413 [==============================] - 1s 2ms/step - loss: 0.3052 - root_mean_squared_error: 0.5524 - val_loss: 0.3282 - val_root_mean_squared_error: 0.5729
# Epoch 9/20
# 413/413 [==============================] - 1s 2ms/step - loss: 0.2966 - root_mean_squared_error: 0.5446 - val_loss: 0.3113 - val_root_mean_squared_error: 0.5580
# Epoch 10/20
# 413/413 [==============================] - 1s 2ms/step - loss: 0.2935 - root_mean_squared_error: 0.5417 - val_loss: 0.3303 - val_root_mean_squared_error: 0.5748
# Epoch 11/20
# 413/413 [==============================] - 1s 2ms/step - loss: 0.2882 - root_mean_squared_error: 0.5368 - val_loss: 0.3166 - val_root_mean_squared_error: 0.5627
# Epoch 12/20
# 413/413 [==============================] - 1s 2ms/step - loss: 0.2864 - root_mean_squared_error: 0.5352 - val_loss: 0.3315 - val_root_mean_squared_error: 0.5757
# Epoch 13/20
# 413/413 [==============================] - 1s 2ms/step - loss: 0.2851 - root_mean_squared_error: 0.5340 - val_loss: 0.3071 - val_root_mean_squared_error: 0.5542
# Epoch 14/20
# 413/413 [==============================] - 1s 2ms/step - loss: 0.2797 - root_mean_squared_error: 0.5288 - val_loss: 0.3090 - val_root_mean_squared_error: 0.5559
# Epoch 15/20
# 413/413 [==============================] - 1s 2ms/step - loss: 0.2729 - root_mean_squared_error: 0.5224 - val_loss: 0.3154 - val_root_mean_squared_error: 0.5616
# Epoch 16/20
# 413/413 [==============================] - 1s 2ms/step - loss: 0.2732 - root_mean_squared_error: 0.5227 - val_loss: 0.2970 - val_root_mean_squared_error: 0.5450
# Epoch 17/20
# 413/413 [==============================] - 1s 2ms/step - loss: 0.2712 - root_mean_squared_error: 0.5207 - val_loss: 0.3027 - val_root_mean_squared_error: 0.5502
# Epoch 18/20
# 413/413 [==============================] - 1s 2ms/step - loss: 0.2679 - root_mean_squared_error: 0.5176 - val_loss: 0.3008 - val_root_mean_squared_error: 0.5484
# Epoch 19/20
# 413/413 [==============================] - 1s 2ms/step - loss: 0.2652 - root_mean_squared_error: 0.5149 - val_loss: 0.3014 - val_root_mean_squared_error: 0.5490
# Epoch 20/20
# 413/413 [==============================] - 1s 2ms/step - loss: 0.2610 - root_mean_squared_error: 0.5109 - val_loss: 0.3008 - val_root_mean_squared_error: 0.5484

# %%
plt.figure(figsize=(8, 5))
for key, style in zip(history.history, ["r--", "r--.", "b-", "b-*"]):
    epochs = np.array(history.epoch) + (0 if key.startswith("val_") else -0.5)
    plt.plot(epochs, history.history[key], style, label=key)
plt.xlabel("Epoch")
plt.axis([-0.5, 19, 0., 1])
plt.legend(loc="lower left")
plt.grid()
plt.show()

# %% [markdown]
# # Run Predictions

# %%
loss_test, rmse_test = model.evaluate(X_test, y_test)
print(loss_test, rmse_test)
# Out:
# 129/129 [==============================] - 0s 1ms/step - loss: 0.3049 - root_mean_squared_error: 0.5522
# 0.30489808320999146 0.552175760269165
